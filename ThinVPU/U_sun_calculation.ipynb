# %%
#importing the libraries 
import pandas as pd
import numpy as np
import math

#Read the .txt metadata dataset 
df=pd.read_csv(r'C:\Users\s\Desktop\Capstone\meta data\crater.txt',delimiter=",")
df.head(3)

# #Reading the columns name
# for col in df.columns: 
#     print(col)
# Out:
#         Product       Pds dataset name Pds volume name Instrument host  \
# 0  M103796812RE  LRO-L-LROC-2-EDR-V1.0     LROLRC_0001             LRO
# 1  M103775477LE  LRO-L-LROC-2-EDR-V1.0     LROLRC_0001             LRO
# 2  M103796812LE  LRO-L-LROC-2-EDR-V1.0     LROLRC_0001             LRO
#
#   Instrument Original product Product version Mission phase name  \
# 0       LROC     nacr00002aa6            v1.8      COMMISSIONING
# 1       LROC     nacl00002aab            v1.8      COMMISSIONING
# 2       LROC     nacl00002aa6            v1.8      COMMISSIONING
#
#           Rationale desc  Data quality          ...           \
# 0  TARGET OF OPPORTUNITY             0          ...
# 1  TARGET OF OPPORTUNITY             0          ...
# 2  TARGET OF OPPORTUNITY             0          ...
#
#   Lower left latitude Lower left longitude Upper left latitude  \
# 0               -2.64               109.36               -0.67
# 1               -9.56               112.49               -7.74
# 2               -2.64               109.19               -0.68
#
#    Upper left longitude Spacecraft altitude Target center distance  \
# 0                109.36              107.99                1845.23
# 1                112.49               99.73                1836.98
# 2                109.18              107.99                1845.23
#
#                                                  EDR  \
# 0  http://lroc.sese.asu.edu/data/LRO-L-LROC-2-EDR...
# 1  http://lroc.sese.asu.edu/data/LRO-L-LROC-2-EDR...
# 2  http://lroc.sese.asu.edu/data/LRO-L-LROC-2-EDR...
#
#                                                  CDR  \
# 0  http://lroc.sese.asu.edu/data/LRO-L-LROC-3-CDR...
# 1  http://lroc.sese.asu.edu/data/LRO-L-LROC-3-CDR...
# 2  http://lroc.sese.asu.edu/data/LRO-L-LROC-3-CDR...
#
#       CDR PTIF (multi-resolution, lossy compression)            Image Name
# 0  http://lroc.sese.asu.edu/data/LRO-L-LROC-3-CDR...  M103796812RC_pyr.tif
# 1  http://lroc.sese.asu.edu/data/LRO-L-LROC-3-CDR...  M103775477LC_pyr.tif
# 2  http://lroc.sese.asu.edu/data/LRO-L-LROC-3-CDR...  M103796812LC_pyr.tif
#
# [3 rows x 68 columns]

# %%
new = df[['Image Name','Lro flight direction','North azimuth' , 'Sub solar azimuth']]
new.dtypes
# Out:
# Image Name               object
# Lro flight direction     object
# North azimuth           float64
# Sub solar azimuth       float64
# dtype: object

# %%
# N_Azimuth= 87.92
# Sub_Azimuth= 209.24

lro_4direction = new.loc[((new['Lro flight direction'] == '-X') & (new['North azimuth'] < 180 ))]



Theta4 = (lro_4direction['North azimuth'] - 90)
Angle_Sun= (lro_4direction ['Sub solar azimuth'] + Theta4)

U4 = ((Angle_Sun + 180) - 360)

lro_4direction['U_sun_x'] = np.cos(-U4)
lro_4direction['U_sun_y']= np.sin(-U4)

lro_4direction
# Out:
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
#                    Image Name Lro flight direction  North azimuth  \
# 0        M103796812RC_pyr.tif                   -X          90.78
# 1        M103775477LC_pyr.tif                   -X          87.97
# 2        M103796812LC_pyr.tif                   -X          88.15
# 3        M103775477RC_pyr.tif                   -X          90.96
# 4        M103803961LC_pyr.tif                   -X          88.15
# 5        M103811313LC_pyr.tif                   -X          87.83
# 6        M103811313RC_pyr.tif                   -X          90.95
# 7        M103803961RC_pyr.tif                   -X          90.76
# 8        M103818471LC_pyr.tif                   -X          87.83
# 9        M103818471RC_pyr.tif                   -X          90.95
# 10       M103825623RC_pyr.tif                   -X          90.94
# 11       M103825623LC_pyr.tif                   -X          87.84
# 12       M103832773LC_pyr.tif                   -X          87.85
# 13       M103839931RC_pyr.tif                   -X          90.93
# 14       M103832773RC_pyr.tif                   -X          90.93
# 15       M103839931LC_pyr.tif                   -X          87.84
# 16       M103847075LC_pyr.tif                   -X          87.86
# 17       M106138968RC_pyr.tif                   -X          90.92
# 18       M103847075RC_pyr.tif                   -X          90.90
# 19       M106138859RC_pyr.tif                   -X          90.81
# 20       M106138968LC_pyr.tif                   -X          87.93
# 21       M106145934RC_pyr.tif                   -X          90.70
# 22       M106146129LC_pyr.tif                   -X          87.94
# 23       M106145934LC_pyr.tif                   -X          88.23
# 24       M106146129RC_pyr.tif                   -X          90.89
# 25       M106153328LC_pyr.tif                   -X          87.89
# 26       M106160506RC_pyr.tif                   -X          90.90
# 27       M106153328RC_pyr.tif                   -X          90.90
# 28       M106160506LC_pyr.tif                   -X          87.87
# 29       M106167682RC_pyr.tif                   -X          90.89
# ...                       ...                  ...            ...
# 291198  M1312741942LC_pyr.tif                   -X          84.68
# 291199  M1312741942RC_pyr.tif                   -X          86.57
# 291200  M1312748985RC_pyr.tif                   -X          86.64
# 291201  M1312748985LC_pyr.tif                   -X          84.71
# 291202  M1312769990RC_pyr.tif                   -X          86.65
# 291203  M1312769990LC_pyr.tif                   -X          84.82
# 291204  M1312777016RC_pyr.tif                   -X          86.71
# 291260  M1338580159RC_pyr.tif                   -X          86.29
# 291261  M1338580159LC_pyr.tif                   -X          84.39
# 291262  M1338587186RC_pyr.tif                   -X          86.31
# 291263  M1338587186LC_pyr.tif                   -X          84.43
# 291264  M1338601308LC_pyr.tif                   -X          84.49
# 291265  M1338601308RC_pyr.tif                   -X          86.46
# 291266  M1338615385RC_pyr.tif                   -X          86.54
# 291267  M1338615385LC_pyr.tif                   -X          84.55
# 291268  M1340936224RC_pyr.tif                   -X          86.26
# 291269  M1340936224LC_pyr.tif                   -X          84.40
# 291270  M1340943387LC_pyr.tif                   -X          84.40
# 291271  M1340943387RC_pyr.tif                   -X          86.50
# 291272  M1340957394LC_pyr.tif                   -X          84.49
# 291273  M1340957394RC_pyr.tif                   -X          86.48
# 291274  M1340964390LC_pyr.tif                   -X          84.54
# 291275  M1340964390RC_pyr.tif                   -X          86.46
# 291276  M1340971410RC_pyr.tif                   -X          86.47
# 291277  M1343277250RC_pyr.tif                   -X          86.39
# 291278  M1343277250LC_pyr.tif                   -X          84.30
# 291279  M1343291287LC_pyr.tif                   -X          84.38
# 291280  M1343291287RC_pyr.tif                   -X          86.43
# 291281  M1343298321LC_pyr.tif                   -X          84.41
# 291282  M1343298321RC_pyr.tif                   -X          86.46
#
#         Sub solar azimuth   U_sun_x   U_sun_y
# 0                  178.97  0.968912  0.247404
# 1                  175.26  0.883827  0.467813
# 2                  179.27 -0.846408  0.532535
# 3                  175.09 -0.690651 -0.723188
# 4                  179.53 -0.681056  0.732231
# 5                  173.79 -0.502094  0.864813
# 6                  173.67  0.619112 -0.785303
# 7                  179.23  0.999950  0.010000
# 8                  173.77 -0.519289  0.854599
# 9                  173.65  0.634693 -0.772764
# 10                 173.78  0.537619 -0.843188
# 11                 173.91 -0.385748  0.922604
# 12                 174.10 -0.194765  0.980850
# 13                 173.91  0.432813 -0.901484
# 14                 173.96  0.387217 -0.921989
# 15                 174.05 -0.253231  0.967406
# 16                 174.42  0.133581  0.991038
# 17                 168.87 -0.707231 -0.706982
# 18                 174.28  0.107403 -0.994216
# 19                 177.22 -0.388685  0.921371
# 20                 168.98  0.866010  0.500027
# 21                 184.54  0.503471  0.864012
# 22                 169.97  0.888665 -0.458557
# 23                 184.98 -0.997661  0.068354
# 24                 169.84 -0.988046  0.154161
# 25                 168.22  0.244658  0.969609
# 26                 167.83  0.270994 -0.962581
# 27                 168.12 -0.015574 -0.999879
# 28                 167.92 -0.072769  0.997349
# 29                 167.89  0.222547 -0.974922
# ...                   ...       ...       ...
# 291198             210.08  0.931333  0.364170
# 291199             209.27  0.760146 -0.649752
# 291200             207.22  0.293662  0.955909
# 291201             208.00 -0.752563  0.658521
# 291202             212.19 -0.844232  0.535978
# 291203             213.04 -0.915385 -0.402580
# 291204             211.73 -0.986309  0.164909
# 291260             182.82  0.629412  0.777072
# 291261             183.24 -0.716801  0.697278
# 291262             183.02  0.783822  0.620986
# 291263             183.45 -0.522008  0.852940
# 291264             182.52 -0.988532  0.151013
# 291265             182.12  0.150225  0.988652
# 291266             182.05  0.160104  0.987100
# 291267             182.44 -0.991354  0.131213
# 291268             195.65  0.792212  0.610246
# 291269             196.34 -0.252801  0.967518
# 291270             189.36 -0.814803  0.579738
# 291271             188.83  0.579089  0.815264
# 291272             192.61  0.684547 -0.728969
# 291273             192.00 -0.585923 -0.810367
# 291274             194.73 -0.988046 -0.154161
# 291275             194.07 -0.448936  0.893564
# 291276             195.12  0.560033  0.828470
# 291277             217.65 -0.869049 -0.494726
# 291278             218.58  0.106520 -0.994311
# 291279             221.41 -0.331899  0.943315
# 291280             220.45  0.682870  0.730540
# 291281             221.40 -0.312967  0.949764
# 291282             220.43  0.690141  0.723675
#
# [69391 rows x 6 columns]

# %%
lro_3direction = new.loc[((new['Lro flight direction'] == '-X') & (new['North azimuth'] >= 180 ))]


Theta3 = (lro_3direction['North azimuth'] - 270)
Angle_Sun= (lro_3direction ['Sub solar azimuth'] + Theta3)

U3 = ((Angle_Sun + 180) - 360)

lro_3direction['U_sun_x'] = np.cos(-U3)
lro_3direction['U_sun_y']= np.sin(-U3)

lro_3direction
# Out:
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                    Image Name Lro flight direction  North azimuth  \
# 52       M108543014RC_pyr.tif                   -X         253.60
# 54       M108543014LC_pyr.tif                   -X         257.27
# 173      M126194809RC_pyr.tif                   -X         269.07
# 174      M126195039LC_pyr.tif                   -X         272.45
# 175      M126194809LC_pyr.tif                   -X         272.84
# 176      M126195039RC_pyr.tif                   -X         269.32
# 177      M126201680LC_pyr.tif                   -X         272.71
# 178      M126201760RC_pyr.tif                   -X         269.27
# 179      M126201680RC_pyr.tif                   -X         269.17
# 180      M126208539LC_pyr.tif                   -X         272.61
# 181      M126208539RC_pyr.tif                   -X         269.27
# 182      M126208614RC_pyr.tif                   -X         269.35
# 183      M126208614LC_pyr.tif                   -X         272.49
# 184      M126201760LC_pyr.tif                   -X         272.57
# 185      M126221998LC_pyr.tif                   -X         272.84
# 186      M126215352LC_pyr.tif                   -X         272.58
# 187      M126215352RC_pyr.tif                   -X         269.31
# 188      M126221998RC_pyr.tif                   -X         269.16
# 189      M126228884LC_pyr.tif                   -X         272.68
# 190      M126222149RC_pyr.tif                   -X         269.33
# 191      M126222149LC_pyr.tif                   -X         272.58
# 192      M126228884RC_pyr.tif                   -X         269.27
# 193      M126228943RC_pyr.tif                   -X         269.34
# 194      M126228943LC_pyr.tif                   -X         272.57
# 195      M126235572RC_pyr.tif                   -X         269.17
# 196      M126235572LC_pyr.tif                   -X         272.85
# 197      M126242475RC_pyr.tif                   -X         269.28
# 198      M126242537RC_pyr.tif                   -X         269.36
# 199      M126242475LC_pyr.tif                   -X         272.65
# 200      M126235755LC_pyr.tif                   -X         272.54
# ...                       ...                  ...            ...
# 291180  M1302179760RC_pyr.tif                   -X         272.87
# 291181  M1302179760LC_pyr.tif                   -X         275.52
# 291182  M1302186758RC_pyr.tif                   -X         272.79
# 291183  M1302186758LC_pyr.tif                   -X         275.49
# 291184  M1302200854RC_pyr.tif                   -X         272.79
# 291185  M1302200854LC_pyr.tif                   -X         275.42
# 291186  M1304513721RC_pyr.tif                   -X         272.92
# 291187  M1304513721LC_pyr.tif                   -X         275.62
# 291188  M1304520697RC_pyr.tif                   -X         272.81
# 291189  M1304520697LC_pyr.tif                   -X         275.61
# 291190  M1304527700RC_pyr.tif                   -X         272.73
# 291191  M1304527700LC_pyr.tif                   -X         275.58
# 291192  M1304534815RC_pyr.tif                   -X         272.83
# 291193  M1304534815LC_pyr.tif                   -X         275.51
# 291244  M1332716668LC_pyr.tif                   -X         275.87
# 291245  M1332716668RC_pyr.tif                   -X         273.16
# 291246  M1332723724LC_pyr.tif                   -X         275.83
# 291247  M1332723724RC_pyr.tif                   -X         273.16
# 291248  M1332730762RC_pyr.tif                   -X         273.12
# 291249  M1332730762LC_pyr.tif                   -X         275.79
# 291250  M1332737739LC_pyr.tif                   -X         275.79
# 291251  M1332737739RC_pyr.tif                   -X         272.99
# 291252  M1335067128RC_pyr.tif                   -X         273.22
# 291253  M1335067128LC_pyr.tif                   -X         275.89
# 291254  M1335074129RC_pyr.tif                   -X         273.10
# 291255  M1335074129LC_pyr.tif                   -X         275.86
# 291256  M1335074165LC_pyr.tif                   -X         275.85
# 291257  M1335074165RC_pyr.tif                   -X         273.18
# 291258  M1335095208LC_pyr.tif                   -X         275.77
# 291259  M1335095208RC_pyr.tif                   -X         272.97
#
#         Sub solar azimuth   U_sun_x   U_sun_y
# 52                 290.97  0.948535 -0.316673
# 54                 291.99  0.295359  0.955386
# 173                211.22  0.430340  0.902667
# 174                180.59 -0.994844 -0.101418
# 175                211.98 -0.965749  0.259477
# 176                180.24  0.904752  0.425939
# 177                202.93  0.874079 -0.485783
# 178                190.23 -0.997172  0.075151
# 179                202.28 -0.857118 -0.515121
# 180                193.33 -0.973200  0.229960
# 181                192.81  0.884035  0.467420
# 182                180.62  0.999550  0.029996
# 183                180.98 -0.946557  0.322536
# 184                190.72  0.749408 -0.662109
# 185                208.34  0.972298  0.233744
# 186                188.73  0.309270  0.950974
# 187                188.27  0.270567 -0.962701
# 188                207.63 -0.086355 -0.996264
# 189                196.41  0.971232 -0.238134
# 190                187.15  0.980694 -0.195547
# 191                187.59 -0.734937  0.678135
# 192                195.85 -0.832072 -0.554667
# 193                186.33  0.817819  0.575475
# 194                186.76 -0.995512 -0.094636
# 195                207.72 -0.185384 -0.982666
# 196                208.44  0.992082  0.125594
# 197                193.83  0.855837 -0.517246
# 198                183.78 -0.999999 -0.001593
# 199                194.36 -0.265536  0.964101
# 200                183.33  0.915846  0.401529
# ...                   ...       ...       ...
# 291180             158.71  0.909151 -0.416467
# 291181             158.65 -0.992563 -0.121734
# 291182             160.72 -0.709480 -0.704726
# 291183             160.70  0.321362  0.946957
# 291184             158.05  0.952198  0.305482
# 291185             157.98 -0.627828 -0.778352
# 291186             174.76 -0.681056  0.732231
# 291187             174.92  0.857709 -0.514136
# 291188             176.41  0.710914  0.703279
# 291189             176.62 -0.612488 -0.790480
# 291190             177.16  0.993956  0.109778
# 291191             177.39 -0.985314 -0.170752
# 291192             174.44 -0.916485  0.400069
# 291193             174.59  0.995004 -0.099833
# 291244             168.15  0.954390 -0.298562
# 291245             168.07 -0.793183  0.608983
# 291246             167.03  0.654848  0.755761
# 291247             166.96 -0.898163 -0.439662
# 291248             166.97 -0.884571 -0.466405
# 291249             167.04  0.631884  0.775063
# 291250             171.16 -0.995808  0.091465
# 291251             171.01  0.960170 -0.279415
# 291252             177.65  0.644827 -0.764329
# 291253             177.88 -0.808965  0.587857
# 291254             178.71 -0.236929 -0.971527
# 291255             178.99  0.137177  0.990547
# 291256             177.93 -0.803046  0.595917
# 291257             177.70  0.637151 -0.770739
# 291258             179.33  0.377978  0.925815
# 291259             179.04 -0.425219 -0.905091
#
# [82658 rows x 6 columns]

# %%
lro_2direction = new.loc[((new['Lro flight direction'] == '+X') & (new['North azimuth'] >= 180 ))]


Theta2 = (270 - lro_2direction['North azimuth'] )
Angle_Sun= (lro_2direction ['Sub solar azimuth'] + Theta2)

U2 = Angle_Sun + 180

lro_2direction['U_sun_x'] = np.cos(U2)
lro_2direction['U_sun_y']= np.sin(U2)

lro_2direction
# Out:
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                    Image Name Lro flight direction  North azimuth  \
# 59       M110852680LC_pyr.tif                   +X         268.54
# 60       M110852680RC_pyr.tif                   +X         264.90
# 63       M110866130LC_pyr.tif                   +X         271.59
# 64       M110866130RC_pyr.tif                   +X         268.29
# 65       M110859347LC_pyr.tif                   +X         271.61
# 66       M110859347RC_pyr.tif                   +X         268.30
# 67       M110879850RC_pyr.tif                   +X         268.10
# 68       M110872912RC_pyr.tif                   +X         268.29
# 69       M110872912LC_pyr.tif                   +X         271.56
# 70       M110879850LC_pyr.tif                   +X         271.79
# 71       M110886482RC_pyr.tif                   +X         268.28
# 72       M110886482LC_pyr.tif                   +X         271.54
# 73       M110893263RC_pyr.tif                   +X         268.29
# 74       M110893263LC_pyr.tif                   +X         271.52
# 75       M110900080RC_pyr.tif                   +X         268.26
# 76       M110906988LC_pyr.tif                   +X         271.76
# 77       M110900080LC_pyr.tif                   +X         271.56
# 78       M110906988RC_pyr.tif                   +X         268.12
# 79       M110913700RC_pyr.tif                   +X         268.22
# 80       M110920477RC_pyr.tif                   +X         268.23
# 81       M110913700LC_pyr.tif                   +X         271.62
# 82       M110920477LC_pyr.tif                   +X         271.61
# 83       M113215869RC_pyr.tif                   +X         268.14
# 84       M113222662LC_pyr.tif                   +X         271.77
# 85       M113215869LC_pyr.tif                   +X         271.79
# 86       M113222662RC_pyr.tif                   +X         268.13
# 87       M113243044LC_pyr.tif                   +X         271.73
# 88       M113236259RC_pyr.tif                   +X         268.08
# 89       M113236259LC_pyr.tif                   +X         271.76
# 90       M113243044RC_pyr.tif                   +X         268.09
# ...                       ...                  ...            ...
# 291145  M1289263579LC_pyr.tif                   +X         267.79
# 291146  M1289263579RC_pyr.tif                   +X         265.07
# 291147  M1289270559LC_pyr.tif                   +X         267.75
# 291205  M1315085359RC_pyr.tif                   +X         264.71
# 291206  M1315085359LC_pyr.tif                   +X         267.38
# 291207  M1315092377LC_pyr.tif                   +X         267.42
# 291208  M1315092377RC_pyr.tif                   +X         264.75
# 291209  M1315099383RC_pyr.tif                   +X         264.78
# 291210  M1315099383LC_pyr.tif                   +X         267.43
# 291211  M1315106462RC_pyr.tif                   +X         264.81
# 291212  M1315106462LC_pyr.tif                   +X         267.59
# 291213  M1315113399RC_pyr.tif                   +X         264.85
# 291214  M1315113399LC_pyr.tif                   +X         267.46
# 291215  M1315127424LC_pyr.tif                   +X         267.52
# 291216  M1317444594LC_pyr.tif                   +X         267.48
# 291217  M1317444594RC_pyr.tif                   +X         264.74
# 291218  M1317451606LC_pyr.tif                   +X         267.48
# 291219  M1317451606RC_pyr.tif                   +X         264.77
# 291220  M1317465604RC_pyr.tif                   +X         264.83
# 291221  M1317465604LC_pyr.tif                   +X         267.43
# 291222  M1319792336RC_pyr.tif                   +X         264.70
# 291223  M1319792336LC_pyr.tif                   +X         267.45
# 291224  M1319813389RC_pyr.tif                   +X         264.79
# 291225  M1319813389LC_pyr.tif                   +X         267.47
# 291226  M1319820415RC_pyr.tif                   +X         264.83
# 291227  M1319820415LC_pyr.tif                   +X         267.49
# 291283  M1345623440RC_pyr.tif                   +X         264.38
# 291284  M1345637555RC_pyr.tif                   +X         264.45
# 291285  M1345651553RC_pyr.tif                   +X         264.51
# 291286  M1345658644RC_pyr.tif                   +X         264.55
#
#         Sub solar azimuth   U_sun_x   U_sun_y
# 59                 198.15 -0.866469  0.499231
# 60                 197.59  0.834096 -0.551619
# 63                 179.91  0.984122  0.177492
# 64                 179.57 -0.999995  0.003155
# 65                 181.01  0.307304  0.951611
# 66                 180.65 -0.482890 -0.875681
# 67                 198.68 -0.901623 -0.432523
# 68                 178.50 -0.477354  0.878711
# 69                 178.83  0.643631 -0.765336
# 70                 199.29  0.873290  0.487201
# 71                 177.17  0.732753  0.680495
# 72                 177.48 -0.589764 -0.807576
# 73                 175.94  0.881596 -0.472004
# 74                 176.23 -0.958252  0.285923
# 75                 179.80 -0.967196 -0.254030
# 76                 196.53 -0.605443 -0.795889
# 77                 180.14  0.905416  0.424525
# 78                 195.96  0.660823  0.750542
# 79                 185.04 -0.734178  0.678957
# 80                 184.14  0.085440  0.996343
# 81                 185.46  0.833851 -0.551989
# 82                 184.55  0.085942 -0.996300
# 83                 185.37 -0.943969  0.330035
# 84                 185.58  0.816919 -0.576753
# 85                 185.83  0.926893 -0.375325
# 86                 185.12 -0.838463  0.544959
# 87                 185.50  0.793202 -0.608959
# 88                 185.74 -0.995617 -0.093523
# 89                 186.22  0.999379  0.035245
# 90                 185.05 -0.821739  0.569864
# ...                   ...       ...       ...
# 291145             167.44 -0.595253 -0.803538
# 291146             167.45  0.867012  0.498288
# 291147             166.03 -0.906117  0.423028
# 291205             108.40 -0.048894 -0.998804
# 291206             107.95  0.027317  0.999627
# 291207             108.58 -0.533455  0.845829
# 291208             109.03  0.515068 -0.857149
# 291209             108.67  0.150513 -0.988608
# 291210             108.23 -0.201295  0.979531
# 291211             113.80 -0.858377 -0.513019
# 291212             113.36  0.895923  0.444208
# 291213             107.96 -0.588266 -0.808667
# 291214             107.52  0.511836  0.859083
# 291215             107.81  0.302506  0.953148
# 291216             158.99 -0.602953  0.797777
# 291217             159.05  0.300870 -0.953665
# 291218             157.95  0.382779  0.923840
# 291219             158.03 -0.677527 -0.735498
# 291220             154.56  0.905605  0.424123
# 291221             154.41 -0.675181 -0.737652
# 291222             170.38 -0.777554 -0.628816
# 291223             170.40  0.461046  0.887376
# 291224             169.46 -0.946052  0.324015
# 291225             169.45  0.992613  0.121323
# 291226             169.39 -0.904765  0.425912
# 291227             169.37  0.999766  0.021621
# 291283             134.60  0.975360 -0.220621
# 291284             141.87  0.768461  0.639897
# 291285             136.91 -0.377183  0.926139
# 291286             143.87 -0.853970  0.520323
#
# [72725 rows x 6 columns]

# %%
lro_1direction = new.loc[((new['Lro flight direction'] == '+X') & (new['North azimuth'] < 180 ))]


Theta1 = (270 - lro_1direction['North azimuth'] )
Angle_Sun= (lro_1direction ['Sub solar azimuth'] + Theta1)

U1 = Angle_Sun + 180

lro_1direction['U_sun_x'] = np.cos(U1)
lro_1direction['U_sun_y']= np.sin(U1)

lro_1direction
# Out:
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\s\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#                    Image Name Lro flight direction  North azimuth  \
# 99       M119116150LC_pyr.tif                   +X          88.75
# 100      M119122930RC_pyr.tif                   +X          91.67
# 101      M119122930LC_pyr.tif                   +X          88.75
# 102      M119116150RC_pyr.tif                   +X          91.64
# 103      M119129713LC_pyr.tif                   +X          88.77
# 104      M119136492RC_pyr.tif                   +X          91.72
# 105      M119129713RC_pyr.tif                   +X          91.69
# 106      M119136492LC_pyr.tif                   +X          88.77
# 107      M119150247LC_pyr.tif                   +X          89.08
# 108      M119150247RC_pyr.tif                   +X          91.53
# 109      M119143285LC_pyr.tif                   +X          88.79
# 110      M119143285RC_pyr.tif                   +X          91.72
# 111      M119157022LC_pyr.tif                   +X          89.06
# 112      M119163842RC_pyr.tif                   +X          91.51
# 113      M119157022RC_pyr.tif                   +X          91.54
# 114      M119163842LC_pyr.tif                   +X          89.12
# 115      M119177180RC_pyr.tif                   +X          91.78
# 116      M119170555RC_pyr.tif                   +X          91.58
# 117      M119170555LC_pyr.tif                   +X          89.01
# 118      M119177180LC_pyr.tif                   +X          88.74
# 119      M119184126LC_pyr.tif                   +X          89.01
# 120      M121470818RC_pyr.tif                   +X          91.64
# 121      M121470818LC_pyr.tif                   +X          88.75
# 122      M119184126RC_pyr.tif                   +X          91.59
# 123      M121477597LC_pyr.tif                   +X          88.76
# 124      M121484381RC_pyr.tif                   +X          91.69
# 125      M121477597RC_pyr.tif                   +X          91.67
# 126      M121484381LC_pyr.tif                   +X          88.78
# 127      M121491362RC_pyr.tif                   +X          91.49
# 128      M121491137RC_pyr.tif                   +X          91.74
# ...                       ...                  ...            ...
# 291152  M1295130496RC_pyr.tif                   +X          94.62
# 291153  M1295130496LC_pyr.tif                   +X          92.54
# 291154  M1295137575LC_pyr.tif                   +X          92.61
# 291155  M1295137575RC_pyr.tif                   +X          94.58
# 291156  M1297462867RC_pyr.tif                   +X          94.74
# 291157  M1297462867LC_pyr.tif                   +X          92.80
# 291158  M1297483917RC_pyr.tif                   +X          94.62
# 291159  M1297483917LC_pyr.tif                   +X          92.62
# 291160  M1297490897LC_pyr.tif                   +X          92.50
# 291161  M1297490897RC_pyr.tif                   +X          94.60
# 291162  M1297497974LC_pyr.tif                   +X          92.55
# 291163  M1297497974RC_pyr.tif                   +X          94.56
# 291164  M1297505022LC_pyr.tif                   +X          92.59
# 291165  M1297505022RC_pyr.tif                   +X          94.54
# 291228  M1325676195LC_pyr.tif                   +X          93.06
# 291229  M1325676195RC_pyr.tif                   +X          94.95
# 291230  M1325683204LC_pyr.tif                   +X          92.96
# 291231  M1325683204RC_pyr.tif                   +X          94.91
# 291232  M1325690265RC_pyr.tif                   +X          94.88
# 291233  M1325690265LC_pyr.tif                   +X          92.96
# 291234  M1328012717RC_pyr.tif                   +X          95.03
# 291235  M1328012717LC_pyr.tif                   +X          92.97
# 291236  M1328033901RC_pyr.tif                   +X          94.94
# 291237  M1328033901LC_pyr.tif                   +X          92.99
# 291238  M1328040913LC_pyr.tif                   +X          92.89
# 291239  M1328040913RC_pyr.tif                   +X          94.89
# 291240  M1328047959LC_pyr.tif                   +X          92.86
# 291241  M1328047959RC_pyr.tif                   +X          94.86
# 291242  M1328055036RC_pyr.tif                   +X          94.85
# 291243  M1328055036LC_pyr.tif                   +X          92.93
#
#         Sub solar azimuth   U_sun_x   U_sun_y
# 99                 176.07 -0.994211 -0.107448
# 100                175.71  0.999527 -0.030746
# 101                175.90 -0.998057  0.062303
# 102                175.88  0.985712  0.168442
# 103                175.80 -0.983421  0.181335
# 104                175.41  0.928386 -0.371618
# 105                175.62  0.990111 -0.140287
# 106                175.58 -0.920146  0.391576
# 107                180.55  0.439222  0.898378
# 108                180.22 -0.093005 -0.995666
# 109                175.74 -0.965785  0.259345
# 110                175.55  0.971159 -0.238432
# 111                180.23  0.685094  0.728455
# 112                180.81  0.494153 -0.869375
# 113                179.91 -0.401487 -0.915865
# 114                181.16 -0.115012  0.993364
# 115                174.55  0.266775 -0.963759
# 116                178.86 -0.997712 -0.067605
# 117                179.15  0.977203 -0.212308
# 118                174.70 -0.313097  0.949721
# 119                179.14  0.975031 -0.222069
# 120                167.70 -0.156128 -0.987737
# 121                167.81  0.293955  0.955819
# 122                178.85 -0.998865 -0.047638
# 123                167.28  0.743549  0.668682
# 124                167.13 -0.700979 -0.713182
# 125                167.17 -0.656953 -0.753932
# 126                167.23  0.788497  0.615038
# 127                181.30  0.855678 -0.517508
# 128                165.05 -0.232671  0.972555
# ...                   ...       ...       ...
# 291152             187.95 -0.986331  0.164774
# 291153             188.52  0.791754 -0.610841
# 291154             190.27  0.520911  0.853611
# 291155             189.64 -0.006325 -0.999980
# 291156             203.77  0.984988 -0.172623
# 291157             204.56 -0.833665  0.552270
# 291158             201.63 -0.583227 -0.812309
# 291159             202.37  0.854345  0.519707
# 291160             198.40 -0.986923  0.161193
# 291161             197.73  0.978095  0.208160
# 291162             202.23  0.888602  0.458679
# 291163             201.49 -0.646277 -0.763103
# 291164             204.57 -0.934093  0.357029
# 291165             203.78  0.999334  0.036500
# 291228             194.85  0.426382 -0.904543
# 291229             194.15 -0.837167  0.546948
# 291230             193.71 -0.564239 -0.825612
# 291231             193.03  0.087805  0.996138
# 291232             193.58 -0.472462  0.881351
# 291233             194.27 -0.039500 -0.999220
# 291234             206.03 -0.223800  0.974635
# 291235             206.78 -0.105684 -0.994400
# 291236             211.97  0.027471  0.999623
# 291237             212.82 -0.360745 -0.932664
# 291238             210.51 -0.533325  0.845911
# 291239             209.70  0.779657 -0.626206
# 291240             210.74 -0.732867  0.680372
# 291241             209.93  0.914439 -0.404725
# 291242             213.86 -0.928022 -0.372526
# 291243             214.74  0.999195  0.040126
#
# [66513 rows x 6 columns]
